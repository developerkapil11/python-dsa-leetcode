# %%
class Palindrome:
    def palindrome(self, nums:int) -> str | None:
        nums_copy = nums
        reversed_num = 0
        while nums > 0 :

            reversed_num = reversed_num * 10 + nums % 10
            nums = nums//10
        
        if nums_copy == reversed : return "Number is Palindrome"
        else: return "No Palindrome"

obj = Palindrome()
print(obj.palindrome(121))
print(obj.palindrome(3456))
# Out:
# Number is Palindrome
# No Palindrome
